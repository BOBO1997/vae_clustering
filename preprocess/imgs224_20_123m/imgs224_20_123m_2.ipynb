# %% [markdown]
# # スケールはそのままで、位置だけ揃える

# %%
import cv2
import datetime
import io
from IPython.display import display, Image
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import pickle
import scipy
from scipy import interpolate
from tqdm import tqdm

# %%
import sys
sys.path.append('/home/kwk/share/mizuho/share/code')
sys.path.append("/home/kwk/share/mizuho/u00257/vae_clustering/src/")
sys.path.append("/home/kwk/share/mizuho/u00257/vae_clustering/src/lib/")
sys.path.append("/home/kwk/share/mizuho/u00257/vae_clustering/src/preprocess/")

# %%
from get_data import get_data
import importlib
import img_shows
import gen_functions
from img_shows import *
from gen_functions import *

# %%
delta = 22
df_market, df_economy = get_data()
usgb10 = df_market.USGB10.pct_change(delta)
ussp500 = df_market.US_SP500.pct_change(delta)

# %%
dates = None
with open("../data_pkls/dates123m.pkl", "rb") as f:
    dates = pickle.load(f)

# %%
max_w, max_h = None, None
with open("max_wh.pkl", "rb") as f:
    max_w, max_h = pickle.load(f)
print(max_w, max_h)
# Out:
# 0.7013543007443057 0.41413084844130343

# %%
lw = 20
size = 224
num_divide = 20

# %% [markdown]
# #### 分割2

# %%
img_list = []
for i in tqdm( range(len(dates) // num_divide, len(dates) // num_divide * 2) ):
    img = gen_imgs(dates[i][0], dates[i][1], usgb10, ussp500, max_w, max_h, lw=lw)
    img_list.append(img)
# Out:
# 100%|██████████| 2172/2172 [16:35<00:00,  2.18it/s]

# %%
data_pkls = "../data_pkls/imgs224_20_123m/"
with open(data_pkls + "2.pkl", "wb") as f:
    pickle.dump(img_list, f)

# %%
img_list2 = []
for i in tqdm( range(len(dates) // num_divide * 11, len(dates) // num_divide * 12) ):
    img = gen_imgs(dates[i][0], dates[i][1], usgb10, ussp500, max_w, max_h, lw=lw)
    img_list.append(img)
# Out:
# 100%|██████████| 2172/2172 [16:46<00:00,  2.16it/s]

# %%
data_pkls = "../data_pkls/imgs224_20_123m/"
with open(data_pkls + "12.pkl", "wb") as f:
    pickle.dump(img_list2, f)

# %%
img_list3 = []
for i in tqdm( range(len(dates) // num_divide * 19, len(dates) // num_divide * 20) ):
    img = gen_imgs(dates[i][0], dates[i][1], usgb10, ussp500, max_w, max_h, lw=lw)
    img_list3.append(img)
# Out:
# 100%|██████████| 2172/2172 [16:44<00:00,  2.16it/s]

# %%
data_pkls = "../data_pkls/imgs224_20_123m/"
with open(data_pkls + "20.pkl", "wb") as f:
    pickle.dump(img_list3, f)

# %%
img_list4 = []
for i in tqdm( range(len(dates) // num_divide * 17, len(dates) // num_divide * 18) ):
    img = gen_imgs(dates[i][0], dates[i][1], usgb10, ussp500, max_w, max_h, lw=lw)
    img_list4.append(img)
# Out:
# 100%|██████████| 2172/2172 [16:29<00:00,  2.20it/s]

# %%
data_pkls = "../data_pkls/imgs224_20_123m/"
with open(data_pkls + "18.pkl", "wb") as f:
    pickle.dump(img_list4, f)

# %%
img_list5 = []
for i in tqdm( range(len(dates) // num_divide * 16, len(dates) // num_divide * 17) ):
    img = gen_imgs(dates[i][0], dates[i][1], usgb10, ussp500, max_w, max_h, lw=lw)
    img_list5.append(img)
# Out:
# 100%|██████████| 2172/2172 [16:18<00:00,  2.22it/s]

# %%
data_pkls = "../data_pkls/imgs224_20_123m/"
with open(data_pkls + "17.pkl", "wb") as f:
    pickle.dump(img_list5, f)
